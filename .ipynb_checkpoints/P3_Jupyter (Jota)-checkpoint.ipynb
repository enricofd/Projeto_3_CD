# %% [markdown]
# # Projeto 3

# %%
import pandas as pd
import numpy as np
import re
import string
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy.stats import norm, probplot
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import display
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
PETR4_raw = pd.read_excel (r'PETR4.SA .xltx')

GOLD_raw = pd.read_excel (r'Gold Futures Historical Data.xltx') 
RDS_raw = pd.read_excel (r'RDS-A.xltx') 
OIL_raw = pd.read_excel (r'Crude Oil WTI Futures Historical Data.xltx')
CRD_raw = pd.read_excel (r'USD_BRL Dados Históricos.xltx')

# %%
PETR4 = PETR4_raw[['Date', 'Adj Close']]

GOLD = GOLD_raw[['Date', 'Price']]
RDS = RDS_raw[['Date', 'Adj Close']]
OIL = OIL_raw[['Date', 'Price']]
CRD = CRD_raw[['Data', 'Último']]

# %% [markdown]
# Para PTR4:

# %%
PETR4_RE = PETR4.rename(columns={"Adj Close": "Valor_PETR4"})
PETR4_REDate = PETR4_RE.assign(Date = PETR4_RE.Date.values[::-1])
PETR4_F = PETR4_REDate.assign(Valor_PETR4 = PETR4_REDate.Valor_PETR4.values[::-1])

# %% [markdown]
# Para Gold:

# %%
GOLD_F = GOLD.rename(columns={"Price": "Valor_GOLD"})

# %% [markdown]
# Para RDS:

# %%
RDS_RE = RDS.rename(columns={"Adj Close": "Valor_RDS"})
RDS_REDate = RDS_RE.assign(Date = RDS_RE.Date.values[::-1])
RDS_F = RDS_REDate.assign(Valor_RDS = RDS_REDate.Valor_RDS.values[::-1])

# %% [markdown]
# Para OIL:

# %%
OIL_F = OIL.rename(columns={"Price": "Valor_OIL"})

# %% [markdown]
# Para CRD:

# %%
CRD_RE = CRD.rename(columns={"Data": "Date","Último": "Valor_CRD" })

NOVO_VALOR = []
for e in CRD_RE["Valor_CRD"]:
    NOVO_VALOR.append(e/10000)
CRD_RE['Valor_CRD'] = NOVO_VALOR

NOVA_DATA = []
for e in CRD_RE['Date']:
    Separado = e.split(".")
    Correto = Separado[2] + "-" + Separado[1] + "-" + Separado[0]
    NOVA_DATA.append(Correto)
CRD_RE['Date'] = NOVA_DATA 

CRD_F = CRD_RE

# %% [markdown]
# Selecionando intervalo a ser estudado e alterando o index:

# %%
PETR4_F["Date"] == "2014-11-10" #1240
PETR4_F["Date"] == "2019-10-31" #2
PETR4_DATE = PETR4_F.loc[2: 1240].set_index('Date')

GOLD_F["Date"] == "2014-11-10" #1321
GOLD_F["Date"] == "2019-10-31" #5
GOLD_DATE = GOLD_F.loc[5: 1321].set_index('Date')

RDS_F["Date"] == "2014-11-10" #1256
RDS_F["Date"] == "2019-10-31" #4
RDS_DATE = RDS_F.loc[4: 1256].set_index('Date')

OIL_F["Date"] == "2014-11-10" #1318
OIL_F["Date"] == "2019-10-31" #5
OIL_DATE = OIL_F.loc[5: 1318].set_index('Date')

CRD_F["Date"] == "2014-11-10" #1302
CRD_F["Date"] == "2019-10-31" #4
CRD_DATE = CRD_F.loc[4: 1302].set_index('Date')

# %%
U1 = GOLD_DATE.join(PETR4_DATE)
U2 = RDS_DATE.join(U1)
U3 = OIL_DATE.join(U2)
U4 = CRD_DATE.join(U3)
U5 = U4.interpolate()
DADOS = U5.sort_index(ascending=True, axis=0)

# %%
i = 0
FAZER1 = []
while i < 1298:
    FAZER1.append(DADOS["Valor_GOLD"][i] - DADOS["Valor_GOLD"][i-1])    
    i+=1
    
i = 0
FAZER2 = []
while i < 1298:
    FAZER2.append(DADOS["Valor_RDS"][i] - DADOS["Valor_RDS"][i-1])    
    i+=1
    
i = 0
FAZER3 = []
while i < 1298:
    FAZER3.append(DADOS["Valor_OIL"][i] - DADOS["Valor_OIL"][i-1])    
    i+=1    

i = 0
FAZER4 = []
while i < 1298:
    FAZER4.append(DADOS["Valor_CRD"][i] - DADOS["Valor_CRD"][i-1])    
    i+=1     
    
i = 0
FAZER5 = []
while i < 1298:
    FAZER5.append(DADOS["Valor_PETR4"][i] - DADOS["Valor_PETR4"][i-1])    
    i+=1 
    

DADOS_OPT = DADOS.iloc[1:1298,:]

del FAZER1[0]
del FAZER2[0]
del FAZER3[0]
del FAZER4[0]
del FAZER5[0]

V1 = -min(FAZER1) + max(FAZER1)
FAZERV1 = []
for e in FAZER1:
     FAZERV1.append(abs(e/V1))
        
V2 = -min(FAZER2) + max(FAZER2)
FAZERV2 = []
for e in FAZER2:
     FAZERV2.append(abs(e/V2))

V3 = -min(FAZER3) + max(FAZER3)
FAZERV3 = []
for e in FAZER3:
     FAZERV3.append(abs(e/V3))
        
V4 = -min(FAZER4) + max(FAZER4)
FAZERV4 = []
for e in FAZER4:
     FAZERV4.append(abs(e/V4))

V5 = -min(FAZER5) + max(FAZER5)
FAZERV5 = []
for e in FAZER5:
     FAZERV5.append(abs(e/V5))


    
DADOS_OPT['CALC_GOLD'] = FAZERV1
DADOS_OPT['CALC_RDS'] = FAZERV2
DADOS_OPT['CALC_OIL'] = FAZERV3
DADOS_OPT['CALC_CRD'] = FAZERV4
DADOS_OPT['CALC_PETR4'] = FAZERV5
# Out:
# C:\Users\jotah\Anaconda3\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jotah\Anaconda3\lib\site-packages\ipykernel_launcher.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jotah\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jotah\Anaconda3\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jotah\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
DADOS_OPT
# Out:
#             Valor_CRD  Valor_OIL  Valor_RDS  Valor_GOLD  Valor_PETR4  \
# Date
# 2014-11-11     2.5575      77.94  51.477970     1255.10    13.256026
# 2014-11-12     2.5665      77.18  50.531734     1250.40    13.360181
# 2014-11-13     2.5889      74.21  50.179653     1251.40    12.877283
# 2014-11-14     2.6018      75.82  50.891159     1275.60    12.498541
# 2014-11-17     2.6081      75.64  50.795807     1273.70    11.930425
# 2014-11-18     2.5825      74.61  51.367947     1285.50    11.788397
# 2014-11-19     2.5720      74.58  51.294594     1283.40    12.100860
# 2014-11-20     2.5731      75.58  52.079445     1278.90    12.820473
# 2014-11-21     2.5153      76.51  52.666267     1285.90    13.540086
# 2014-11-24     2.5457      75.78  52.123459     1284.20    13.454869
# 2014-11-25     2.5303      74.09  51.808044     1285.20    13.398057
# 2014-11-26     2.5011      73.69  52.350849     1284.50    13.416993
# 2019-10-01   0.156311  0.065531  0.034117  0.007170    0.007223
# 2019-10-02   0.183495  0.253578  0.074299  0.062632    0.142664
# 2019-10-03   0.057282  0.054135  0.014405  0.095318    0.003612
# 2019-10-04   0.008738  0.044162  0.027293  0.060101    0.041535
# 2019-10-07   0.082524  0.017095  0.004549  0.108604    0.061400
# 2019-10-08   0.004854  0.105420  0.009098  0.024673    0.027088
# 2019-10-09   0.086408  0.015671  0.003033  0.031632    0.090294
# 2019-10-10   0.115534  0.101146  0.072782  0.001898    0.039729
# 2019-10-11   0.118447  0.084051  0.087187  0.000422    0.093905
# 2019-10-14   0.086408  0.004274  0.084155  0.035428    0.009029
# 2019-10-15   0.136893  0.039889  0.059136  0.114298    0.052370
# 2019-10-16   0.101942  0.021369  0.041698  0.060945    0.059594
# 2019-10-17   0.041748  0.109694  0.043215  0.026360    0.048759
# 2019-10-18   0.040777  0.062682  0.011372  0.110924    0.010835
# 2019-10-21   0.058252  0.079777  0.035633  0.037115    0.030700
# 2019-10-22   0.005825  0.094023  0.064443  0.099958    0.144470
# 2019-10-23   0.079612  0.095448  0.137225  0.099747    0.068623
# 2019-10-24   0.087379  0.005699  0.019712  0.014551    0.113770
# 2019-10-25   0.005825  0.022794  0.032600  0.079502    0.167946
# 2019-10-28   0.092233  0.027067  0.064443  0.026993    0.063206
# 2019-10-29   0.049515  0.001425  0.020470  0.016027    0.039729
# 2019-10-30   0.058252  0.017095  0.036391  0.016238    0.046953
#
# [1297 rows x 10 columns]

# %% [markdown]
# ##### REGRESSÃO LINEAR

# %%
#Função utilitária para fazer a regressão com constante adicionada
def regress(X,Y):
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    return results

# %%
DADOS_OPT.columns
# Out:
# Index(['Valor_CRD', 'Valor_OIL', 'Valor_RDS', 'Valor_GOLD', 'Valor_PETR4',
#        'CALC_GOLD', 'CALC_RDS', 'CALC_OIL', 'CALC_CRD', 'CALC_PETR4'],
#       dtype='object')

# %%
#Variáveis do nosso dataset
df = DADOS_OPT[['Valor_CRD', 'Valor_OIL', 'Valor_RDS', 'Valor_GOLD', 'Valor_PETR4', 'CALC_GOLD', 'CALC_RDS', 'CALC_OIL', 'CALC_CRD', 'CALC_PETR4']]

# %%
df.describe()
# Out:
#          Valor_CRD    Valor_OIL    Valor_RDS   Valor_GOLD  Valor_PETR4  \
# count  1297.000000  1297.000000  1297.000000  1297.000000  1297.000000
# mean      3.476241    53.151318    50.456716  1302.706052    15.464385
# std       0.392010     9.631621     9.139196    85.301049     6.710696
# min       2.501100    26.210000    28.818090  1090.500000     3.976808
# 25%       3.179500    46.700000    42.996601  1256.500000     9.809459
# 50%       3.392600    52.410000    48.118477  1302.400000    14.155543
# 75%       3.827200    59.520000    58.919838  1350.100000    20.366940
# max       4.207700    77.940000    68.253716  1560.400000    30.080000
#
#          CALC_GOLD     CALC_RDS     CALC_OIL     CALC_CRD   CALC_PETR4
# count  1297.000000  1297.000000  1297.000000  1297.000000  1297.000000
# mean      0.070372     0.070776     0.066847     0.056849     0.053867
# std       0.066617     0.064594     0.059065     0.053114     0.052421
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.023301     0.023320     0.022745     0.018136     0.018809
# 50%       0.051456     0.052302     0.051554     0.044918     0.041038
# 75%       0.097087     0.097986     0.094011     0.078659     0.070247
# max       0.573786     0.575746     0.610311     0.508646     0.546551

# %%
#Verificando os valores nulos
np.sum(df.isnull());

# %%
#Definindo nossa variável de resposta
Y = df['CALC_PETR4']

# %%
#Definindo os outros parâmtros
X = df[['Valor_CRD', 'Valor_OIL', 'Valor_RDS', 'Valor_GOLD', 'Valor_PETR4', 'CALC_GOLD', 'CALC_RDS', 'CALC_OIL', 'CALC_CRD']]

# %%
#Usando regressão para aplicar o ajuste
results = regress(X,Y)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             CALC_PETR4   R-squared:                       0.154
# Model:                            OLS   Adj. R-squared:                  0.148
# Method:                 Least Squares   F-statistic:                     26.10
# Date:                Mon, 11 Nov 2019   Prob (F-statistic):           1.24e-41
# Time:                        19:44:12   Log-Likelihood:                 2093.0
# No. Observations:                1297   AIC:                            -4166.
# Df Residuals:                    1287   BIC:                            -4114.
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0097      0.036     -0.273      0.785      -0.080       0.060
# Valor_CRD      -0.0016      0.004     -0.364      0.716      -0.010       0.007
# Valor_OIL       0.0010      0.000      3.574      0.000       0.000       0.002
# Valor_RDS      -0.0005      0.000     -1.287      0.198      -0.001       0.000
# Valor_GOLD  -1.042e-05   2.16e-05     -0.482      0.630   -5.28e-05     3.2e-05
# Valor_PETR4     0.0018      0.000      4.186      0.000       0.001       0.003
# CALC_GOLD       0.0307      0.021      1.486      0.137      -0.010       0.071
# CALC_RDS        0.1270      0.023      5.540      0.000       0.082       0.172
# CALC_OIL        0.0828      0.025      3.323      0.001       0.034       0.132
# CALC_CRD        0.1947      0.027      7.293      0.000       0.142       0.247
# ==============================================================================
# Omnibus:                      730.522   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9709.055
# Skew:                           2.334   Prob(JB):                         0.00
# Kurtosis:                      15.565   Cond. No.                     3.50e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **Ajustando R-squared Para as Variáveis que Mais Influenciam o CALC_PETR4**

# %% [markdown]
# * Removendo variáveis com valor-p >10%

# %%
#Removendo Valor_CRD, Valor_RDS, Valor_GOLD e Calc_GOLD
X1 = df[['Valor_OIL', 'Valor_PETR4', 'CALC_RDS', 'CALC_OIL', 'CALC_CRD']]

# %%
#Usando regressão para aplicar o ajuste
results1 = regress(X1, Y)
results1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             CALC_PETR4   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.148
# Method:                 Least Squares   F-statistic:                     46.02
# Date:                Mon, 11 Nov 2019   Prob (F-statistic):           7.68e-44
# Time:                        19:44:12   Log-Likelihood:                 2090.7
# No. Observations:                1297   AIC:                            -4169.
# Df Residuals:                    1291   BIC:                            -4138.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0329      0.008     -4.006      0.000      -0.049      -0.017
# Valor_OIL       0.0008      0.000      4.343      0.000       0.000       0.001
# Valor_PETR4     0.0013      0.000      5.128      0.000       0.001       0.002
# CALC_RDS        0.1269      0.023      5.568      0.000       0.082       0.172
# CALC_OIL        0.0867      0.025      3.492      0.000       0.038       0.135
# CALC_CRD        0.1974      0.026      7.675      0.000       0.147       0.248
# ==============================================================================
# Omnibus:                      730.093   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9722.007
# Skew:                           2.331   Prob(JB):                         0.00
# Kurtosis:                      15.576   Cond. No.                     1.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
